# %% [markdown]
# ## PICASO Colab Setup

# %% [markdown]
# ##  This Google Colaboratory Notebook will copy the needed files for PICASO to your Google Drive and needs to be run only **once** to download the files.
#
# **For reference, the URLs that will be used to download the data are the following and will use about 8G of your Google drive:**
#
# *   Picaso: https://github.com/natashabatalha/picaso.git
# *   Opacities: https://zenodo.org/record/3759675/files/opacities.db?download=1
# *   ck04models: http://ssb.stsci.edu/trds/tarfiles/synphot3.tar.gz
# *   profile.tar: https://zenodo.org/record/1309035/files/profile.tar?download=1
# *   spectra.tar: https://zenodo.org/record/1309035/files/spectra.tar?download=1
# *   virga cloud code (if running cloud models): https://zenodo.org/record/3992294/files/virga.zip?download=1
#
# **This notebook will:**
# *   Create the PICASO/code directory if it doesn't already exist. Note, you can change the directory to something else below before running this notebook, but you will need to make sure you that you reference this other directory in the PICASO Google Colab notebooks, so we recommend keeping it to the default of: PICASO/code.
# *   Install picaso
# *   Download download Resampled Opacity.db and Pysynphot Stellar Data
# *   Download the Sonoroa Spectra and Profile grids
# *   In order to save the the data to your drive, you will be prompted for an authorization key - follow the link, accept the authorization and copy and paste the key - be sure to capture the full key (scroll down).
# *   The tar files will be removed from our drive
#
# **To run this notebook:**
# *   Click on the Runtime menu item
# *   Select Run All
# *   This notebook takes around 15 minutes to download the files.

# %% [markdown]
# #### Google Drive Authorization
# In the next cell, you will be prompted for an authorization key - follow the link, accept the authorization and copy and paste the key in the text box - be sure to capture the full key.   When the cell runs to completion you will see:<br />
# <code>Mounted at /content/drive</code>

# %%
# You will be prompted to sign in for the authorization key to access your Google account
#    Click on the "Go to this URL in  a browser"
#    Click on "Sign in" for the authorization
#    Copy the key (be sure to capture the full key - there may be a scroll bar) and paste the key in the text box and press the return key
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Download Files
# In the next cells, you will confirm the download location and the files will be downloaded.
# "PICASO/code" is the default and you can leave that as-is or change it update the fill in box on the right below.)  But a reminder that all PICASO Google Colab notebooks will need to be updated if you define a different directory.

# %%
 # If you update the directory in the box on the right, re-run this cell
 spectroscopy_dir = 'PICASO/code' #@param {type:"string"}

# %%
# The following creates the directory in your Google Drive and downloads the needed supporting files for the Hands on Session

# make the directories
import os

# Google top level drive dir
drive_dir = "/content/drive/MyDrive/"

# Disk Model Path
spectroscopy_path = os.path.join(drive_dir,spectroscopy_dir)

# Create the directory
try:
    os.makedirs(spectroscopy_path, exist_ok = True)
    print("Directory '%s' created successfully" %spectroscopy_dir)
except OSError as error:
    print("Directory '%s' can not be created")

# Change to the DiskModel Path
os.chdir (spectroscopy_path)

# Install picaso files (but do not install picaso - that will be done in the hands on notebooks)
# !git clone https://github.com/natashabatalha/picaso.git
picaso_dir = spectroscopy_path+"/picaso"
#os.chdir(picaso_dir)
#!python setup.py install

# Setup reference directory
reference_dir = picaso_dir+"/reference"

# Download opacities
opacities_dir = reference_dir+"/opacities"
os.chdir(opacities_dir)
# !wget -O opacities.db https://zenodo.org/record/3759675/files/opacities.db?download=1

# Setup picaso_refdata environment variable
os.environ['picaso_refdata'] = reference_dir+"/"


# Download and link the Pysynphot Stellar Data
#Castelli-Kurucz Atlas: ck04models.
os.chdir(spectroscopy_path)
# Instructions suggest the following but does not work 
#!wget -r "https://archive.stsci.edu/hlsps/reference-atlases/cdbs/grid/ck04models/"
# Instead use this tarfile
# !wget http://ssb.stsci.edu/trds/tarfiles/synphot3.tar.gz
# !gunzip synphot3.tar.gz
# !tar -xvf synphot3.tar
trds_dir = spectroscopy_path+"/grp/redcat/trds"
grid_dir = trds_dir+"/grid"

#Setup PSYN_CSBS environment variable
os.environ['PYSYN_CDBS']=trds_dir


# Sonora 2018: Cloud-free, solar composition, solar C/O substellar atmosphere models and spectra
# From:  https://zenodo.org/record/1309035#.YOIvbC1h1UP
os.chdir(spectroscopy_path)
profile_dir = spectroscopy_path+"/profile"
spectra_dir = spectroscopy_path+"/spectra"
print(spectra_dir)
try:
    os.makedirs(profile_dir, exist_ok=True)
    print("Directory '%s' created successfully" %profile_dir)
except OSError as error:
    print("Directory '%s' can not be created")
# !wget -O flux_table.txt https://zenodo.org/record/1309035/files/flux_table.txt?download=1
# !wget -O flux_table_JWST.txt https://zenodo.org/record/1309035/files/flux_table_JWST.txt?download=1
# !wget -O profile.tar https://zenodo.org/record/1309035/files/profile.tar?download=1
# !tar -xvf profile.tar -C profile
# !wget -O spectra.tar https://zenodo.org/record/1309035/files/spectra.tar?download=1
# !tar -xvf spectra.tar

# For the 4_Clouds notebook  
# !wget -O virga.zip https://zenodo.org/record/3992294/files/virga.zip?download=1
# !unzip virga.zip
virga_dir = spectroscopy_path+'/virga_1e-7'
# Out:
# Directory 'PICASO/code' created successfully
# Cloning into 'picaso'...
# remote: Enumerating objects: 2780, done.
# remote: Counting objects: 100% (1073/1073), done.
# remote: Compressing objects: 100% (504/504), done.
# remote: Total 2780 (delta 646), reused 949 (delta 563), pack-reused 1707
# Receiving objects: 100% (2780/2780), 208.14 MiB | 13.79 MiB/s, done.
# Resolving deltas: 100% (1774/1774), done.
# Checking out files: 100% (152/152), done.
# --2021-08-24 14:18:49--  https://zenodo.org/record/3759675/files/opacities.db?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6043701248 (5.6G) [application/octet-stream]
# Saving to: ‘opacities.db’
#
# opacities.db        100%[===================>]   5.63G  34.4MB/s    in 2m 54s
#
# 2021-08-24 14:21:44 (33.0 MB/s) - ‘opacities.db’ saved [6043701248/6043701248]
#
# --2021-08-24 14:21:44--  http://ssb.stsci.edu/trds/tarfiles/synphot3.tar.gz
# Resolving ssb.stsci.edu (ssb.stsci.edu)... 130.167.165.20
# Connecting to ssb.stsci.edu (ssb.stsci.edu)|130.167.165.20|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ssb.stsci.edu/trds/tarfiles/synphot3.tar.gz [following]
# --2021-08-24 14:21:44--  https://ssb.stsci.edu/trds/tarfiles/synphot3.tar.gz
# Connecting to ssb.stsci.edu (ssb.stsci.edu)|130.167.165.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18076806 (17M) [application/octet-stream]
# Saving to: ‘synphot3.tar.gz’
#
# synphot3.tar.gz     100%[===================>]  17.24M  16.5MB/s    in 1.0s
#
# 2021-08-24 14:21:46 (16.5 MB/s) - ‘synphot3.tar.gz’ saved [18076806/18076806]
#
# grp/redcat/trds/grid/ck04models/AA_README
# grp/redcat/trds/grid/ck04models/catalog.fits
# grp/redcat/trds/grid/ck04models/ckm05/
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_11750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_4000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_6250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_12500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_43000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_4500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_10000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_23000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_7750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_7500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_9500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_38000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_50000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_8000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_11000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_10250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_29000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_5750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_10500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_19000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_13000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_12250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_6000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_47000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_33000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_20000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_46000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_7000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_25000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_17000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_4250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_30000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_34000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_3500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_39000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_24000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_44000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_8750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_42000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_31000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_5000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_4750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_7250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_35000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_22000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_15000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_28000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_12000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_6750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_10750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_11250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_49000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_26000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_37000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_21000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_9000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_9750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_18000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_40000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_6500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_8500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_16000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_32000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_14000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_27000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_5250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_36000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_48000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_9250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_11500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_3750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_41000.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_5500.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_8250.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_12750.fits
# grp/redcat/trds/grid/ck04models/ckm05/ckm05_45000.fits
# grp/redcat/trds/grid/ck04models/ckm10/
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_25000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_12000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_15000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_4250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_12500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_35000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_9000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_23000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_16000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_10000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_46000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_5750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_17000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_14000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_40000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_6000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_31000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_3750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_8500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_5250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_9250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_27000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_18000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_48000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_7250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_33000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_44000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_5500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_50000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_6250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_9500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_10250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_36000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_47000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_41000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_45000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_11750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_24000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_22000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_29000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_7500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_6500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_4000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_12750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_8250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_42000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_32000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_7750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_3500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_8750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_10500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_20000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_37000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_4750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_30000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_8000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_21000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_5000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_43000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_34000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_28000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_6750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_39000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_49000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_12250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_7000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_11000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_26000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_19000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_9750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_10750.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_11250.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_11500.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_13000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_38000.fits
# grp/redcat/trds/grid/ck04models/ckm10/ckm10_4500.fits
# grp/redcat/trds/grid/ck04models/ckm15/
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_18000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_9250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_8750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_12000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_35000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_5500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_6500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_37000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_8500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_6250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_41000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_12500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_3500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_7000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_21000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_5000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_10250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_4750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_9750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_10750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_27000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_8250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_30000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_50000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_10500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_36000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_39000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_33000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_40000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_22000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_17000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_15000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_5250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_12250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_16000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_45000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_46000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_19000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_48000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_6000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_29000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_38000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_24000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_31000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_12750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_14000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_11500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_42000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_43000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_7750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_20000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_9500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_4000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_32000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_9000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_10000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_8000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_23000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_11250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_47000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_7250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_4250.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_11750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_6750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_44000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_13000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_49000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_26000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_28000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_11000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_25000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_5750.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_34000.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_7500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_4500.fits
# grp/redcat/trds/grid/ck04models/ckm15/ckm15_3750.fits
# grp/redcat/trds/grid/ck04models/ckm20/
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_13000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_8000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_41000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_42000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_27000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_14000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_5750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_4000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_24000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_12250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_7750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_19000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_33000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_50000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_39000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_10500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_6000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_9750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_20000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_36000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_6250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_43000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_6500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_11500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_6750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_38000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_11750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_5250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_15000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_10750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_23000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_11250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_47000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_4500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_49000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_12500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_12750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_7000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_48000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_4250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_26000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_3750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_8250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_44000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_11000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_8500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_45000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_31000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_9000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_7500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_5500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_37000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_21000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_29000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_10000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_25000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_8750.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_35000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_40000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_28000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_32000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_9250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_9500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_5000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_34000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_7250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_3500.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_16000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_12000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_30000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_46000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_22000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_18000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_17000.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_10250.fits
# grp/redcat/trds/grid/ck04models/ckm20/ckm20_4750.fits
# grp/redcat/trds/grid/ck04models/ckm25/
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_29000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_12750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_42000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_6750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_33000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_10500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_44000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_37000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_25000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_7500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_16000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_35000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_3750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_8250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_26000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_12250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_18000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_49000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_28000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_3500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_12500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_47000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_19000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_50000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_9250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_8500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_46000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_7750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_10000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_5750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_31000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_45000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_12000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_36000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_11250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_4000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_9750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_10750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_43000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_34000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_7250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_6250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_38000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_8000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_32000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_21000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_7000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_15000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_11500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_39000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_5000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_20000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_23000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_10250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_5250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_48000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_9000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_11750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_17000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_9500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_4500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_8750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_30000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_24000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_27000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_41000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_6000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_5500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_22000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_40000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_11000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_14000.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_4750.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_6500.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_4250.fits
# grp/redcat/trds/grid/ck04models/ckm25/ckm25_13000.fits
# grp/redcat/trds/grid/ck04models/ckp00/
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_12250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_15000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_33000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_35000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_26000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_10000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_39000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_10250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_6250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_5250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_34000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_5000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_32000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_8500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_20000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_13000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_7250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_9000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_48000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_44000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_6500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_38000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_49000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_11000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_8250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_28000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_7000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_23000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_40000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_8000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_5750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_16000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_11250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_47000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_17000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_10750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_6000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_50000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_46000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_18000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_5500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_37000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_7750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_27000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_12000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_7500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_6750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_22000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_9750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_29000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_14000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_21000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_31000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_25000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_24000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_43000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_42000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_4500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_3500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_8750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_3750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_41000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_30000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_4250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_10500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_11500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_4000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_12750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_11750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_45000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_19000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_9250.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_36000.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_4750.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_12500.fits
# grp/redcat/trds/grid/ck04models/ckp00/ckp00_9500.fits
# grp/redcat/trds/grid/ck04models/ckp02/
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_35000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_5250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_37000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_47000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_9250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_27000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_8500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_6500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_45000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_6750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_7250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_6250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_10750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_11000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_14000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_5750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_42000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_50000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_23000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_31000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_7500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_33000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_12750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_5500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_13000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_10000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_3750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_40000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_26000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_7750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_4500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_32000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_10250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_34000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_4000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_8750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_21000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_48000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_11500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_11750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_9750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_9000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_4750.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_43000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_22000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_17000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_8000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_15000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_49000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_8250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_39000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_25000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_46000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_24000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_20000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_12500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_6000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_19000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_11250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_30000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_16000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_12000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_10500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_38000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_9500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_41000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_3500.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_18000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_28000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_4250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_36000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_12250.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_5000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_44000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_29000.fits
# grp/redcat/trds/grid/ck04models/ckp02/ckp02_7000.fits
# grp/redcat/trds/grid/ck04models/ckp05/
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_7000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_9750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_32000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_38000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_28000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_8000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_4500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_12000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_8500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_4000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_7250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_31000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_10750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_3750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_5000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_37000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_3500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_42000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_12500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_6250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_13000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_11250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_21000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_11000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_11750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_8250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_9250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_19000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_6000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_9000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_35000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_47000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_40000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_41000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_8750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_6500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_12750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_26000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_4750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_39000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_25000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_7500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_45000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_46000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_33000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_20000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_50000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_4250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_15000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_12250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_14000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_16000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_22000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_9500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_5250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_17000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_7750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_10250.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_23000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_30000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_24000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_10000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_11500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_34000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_49000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_18000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_6750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_5750.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_36000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_10500.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_43000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_27000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_48000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_44000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_29000.fits
# grp/redcat/trds/grid/ck04models/ckp05/ckp05_5500.fits
# /content/drive/MyDrive/PICASO/code/spectra
# Directory '/content/drive/MyDrive/PICASO/code/profile' created successfully
# --2021-08-24 14:22:12--  https://zenodo.org/record/1309035/files/flux_table.txt?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116154 (113K) [text/plain]
# Saving to: ‘flux_table.txt’
#
# flux_table.txt      100%[===================>] 113.43K  --.-KB/s    in 0.06s
#
# 2021-08-24 14:22:13 (1.76 MB/s) - ‘flux_table.txt’ saved [116154/116154]
#
# --2021-08-24 14:22:13--  https://zenodo.org/record/1309035/files/flux_table_JWST.txt?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 185954 (182K) [text/plain]
# Saving to: ‘flux_table_JWST.txt’
#
# flux_table_JWST.txt 100%[===================>] 181.60K  --.-KB/s    in 0.1s
#
# 2021-08-24 14:22:14 (1.44 MB/s) - ‘flux_table_JWST.txt’ saved [185954/185954]
#
# --2021-08-24 14:22:14--  https://zenodo.org/record/1309035/files/profile.tar?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1566720 (1.5M) [application/octet-stream]
# Saving to: ‘profile.tar’
#
# profile.tar         100%[===================>]   1.49M  7.09MB/s    in 0.2s
#
# 2021-08-24 14:22:15 (7.09 MB/s) - ‘profile.tar’ saved [1566720/1566720]
#
# t1000g1000nc_m0.0.cmp.gz
# t1000g100nc_m0.0.cmp.gz
# t1000g1780nc_m0.0.cmp.gz
# t1000g178nc_m0.0.cmp.gz
# t1000g17nc_m0.0.cmp.gz
# t1000g3160nc_m0.0.cmp.gz
# t1000g316nc_m0.0.cmp.gz
# t1000g31nc_m0.0.cmp.gz
# t1000g562nc_m0.0.cmp.gz
# t1000g56nc_m0.0.cmp.gz
# t1100g1000nc_m0.0.cmp.gz
# t1100g100nc_m0.0.cmp.gz
# t1100g1780nc_m0.0.cmp.gz
# t1100g178nc_m0.0.cmp.gz
# t1100g17nc_m0.0.cmp.gz
# t1100g3160nc_m0.0.cmp.gz
# t1100g316nc_m0.0.cmp.gz
# t1100g31nc_m0.0.cmp.gz
# t1100g562nc_m0.0.cmp.gz
# t1100g56nc_m0.0.cmp.gz
# t1200g1000nc_m0.0.cmp.gz
# t1200g100nc_m0.0.cmp.gz
# t1200g1780nc_m0.0.cmp.gz
# t1200g178nc_m0.0.cmp.gz
# t1200g17nc_m0.0.cmp.gz
# t1200g3160nc_m0.0.cmp.gz
# t1200g316nc_m0.0.cmp.gz
# t1200g31nc_m0.0.cmp.gz
# t1200g562nc_m0.0.cmp.gz
# t1200g56nc_m0.0.cmp.gz
# t1300g1000nc_m0.0.cmp.gz
# t1300g100nc_m0.0.cmp.gz
# t1300g1780nc_m0.0.cmp.gz
# t1300g178nc_m0.0.cmp.gz
# t1300g17nc_m0.0.cmp.gz
# t1300g3160nc_m0.0.cmp.gz
# t1300g316nc_m0.0.cmp.gz
# t1300g31nc_m0.0.cmp.gz
# t1300g562nc_m0.0.cmp.gz
# t1300g56nc_m0.0.cmp.gz
# t1400g1000nc_m0.0.cmp.gz
# t1400g100nc_m0.0.cmp.gz
# t1400g1780nc_m0.0.cmp.gz
# t1400g178nc_m0.0.cmp.gz
# t1400g17nc_m0.0.cmp.gz
# t1400g3160nc_m0.0.cmp.gz
# t1400g316nc_m0.0.cmp.gz
# t1400g31nc_m0.0.cmp.gz
# t1400g562nc_m0.0.cmp.gz
# t1400g56nc_m0.0.cmp.gz
# t1500g1000nc_m0.0.cmp.gz
# t1500g100nc_m0.0.cmp.gz
# t1500g1780nc_m0.0.cmp.gz
# t1500g178nc_m0.0.cmp.gz
# t1500g17nc_m0.0.cmp.gz
# t1500g3160nc_m0.0.cmp.gz
# t1500g316nc_m0.0.cmp.gz
# t1500g31nc_m0.0.cmp.gz
# t1500g562nc_m0.0.cmp.gz
# t1500g56nc_m0.0.cmp.gz
# t1600g1000nc_m0.0.cmp.gz
# t1600g100nc_m0.0.cmp.gz
# t1600g1780nc_m0.0.cmp.gz
# t1600g17nc_m0.0.cmp.gz
# t1600g3160nc_m0.0.cmp.gz
# t1600g316nc_m0.0.cmp.gz
# t1600g31nc_m0.0.cmp.gz
# t1600g562nc_m0.0.cmp.gz
# t1600g56nc_m0.0.cmp.gz
# t1700g1000nc_m0.0.cmp.gz
# t1700g100nc_m0.0.cmp.gz
# t1700g1780nc_m0.0.cmp.gz
# t1700g178nc_m0.0.cmp.gz
# t1700g17nc_m0.0.cmp.gz
# t1700g3160nc_m0.0.cmp.gz
# t1700g316nc_m0.0.cmp.gz
# t1700g31nc_m0.0.cmp.gz
# t1700g562nc_m0.0.cmp.gz
# t1700g56nc_m0.0.cmp.gz
# t1800g1000nc_m0.0.cmp.gz
# t1800g100nc_m0.0.cmp.gz
# t1800g1780nc_m0.0.cmp.gz
# t1800g178nc_m0.0.cmp.gz
# t1800g17nc_m0.0.cmp.gz
# t1800g3160nc_m0.0.cmp.gz
# t1800g316nc_m0.0.cmp.gz
# t1800g31nc_m0.0.cmp.gz
# t1800g562nc_m0.0.cmp.gz
# t1800g56nc_m0.0.cmp.gz
# t1900g1000nc_m0.0.cmp.gz
# t1900g100nc_m0.0.cmp.gz
# t1900g1780nc_m0.0.cmp.gz
# t1900g178nc_m0.0.cmp.gz
# t1900g17nc_m0.0.cmp.gz
# t1900g3160nc_m0.0.cmp.gz
# t1900g316nc_m0.0.cmp.gz
# t1900g31nc_m0.0.cmp.gz
# t1900g562nc_m0.0.cmp.gz
# t1900g56nc_m0.0.cmp.gz
# t2000g1000nc_m0.0.cmp.gz
# t2000g100nc_m0.0.cmp.gz
# t2000g1780nc_m0.0.cmp.gz
# t2000g178nc_m0.0.cmp.gz
# t2000g17nc_m0.0.cmp.gz
# t2000g3160nc_m0.0.cmp.gz
# t2000g316nc_m0.0.cmp.gz
# t2000g31nc_m0.0.cmp.gz
# t2000g562nc_m0.0.cmp.gz
# t2000g56nc_m0.0.cmp.gz
# t200g1000nc_m0.0.cmp.gz
# t200g100nc_m0.0.cmp.gz
# t200g1780nc_m0.0.cmp.gz
# t200g178nc_m0.0.cmp.gz
# t200g17nc_m0.0.cmp.gz
# t200g3160nc_m0.0.cmp.gz
# t200g316nc_m0.0.cmp.gz
# t200g31nc_m0.0.cmp.gz
# t200g562nc_m0.0.cmp.gz
# t200g56nc_m0.0.cmp.gz
# t2100g1000nc_m0.0.cmp.gz
# t2100g100nc_m0.0.cmp.gz
# t2100g1780nc_m0.0.cmp.gz
# t2100g178nc_m0.0.cmp.gz
# t2100g17nc_m0.0.cmp.gz
# t2100g3160nc_m0.0.cmp.gz
# t2100g316nc_m0.0.cmp.gz
# t2100g31nc_m0.0.cmp.gz
# t2100g562nc_m0.0.cmp.gz
# t2100g56nc_m0.0.cmp.gz
# t2200g1000nc_m0.0.cmp.gz
# t2200g100nc_m0.0.cmp.gz
# t2200g1780nc_m0.0.cmp.gz
# t2200g178nc_m0.0.cmp.gz
# t2200g17nc_m0.0.cmp.gz
# t2200g3160nc_m0.0.cmp.gz
# t2200g316nc_m0.0.cmp.gz
# t2200g31nc_m0.0.cmp.gz
# t2200g562nc_m0.0.cmp.gz
# t2200g56nc_m0.0.cmp.gz
# t225g1000nc_m0.0.cmp.gz
# t225g100nc_m0.0.cmp.gz
# t225g1780nc_m0.0.cmp.gz
# t225g178nc_m0.0.cmp.gz
# t225g17nc_m0.0.cmp.gz
# t225g3160nc_m0.0.cmp.gz
# t225g316nc_m0.0.cmp.gz
# t225g31nc_m0.0.cmp.gz
# t225g562nc_m0.0.cmp.gz
# t225g56nc_m0.0.cmp.gz
# t2300g1000nc_m0.0.cmp.gz
# t2300g100nc_m0.0.cmp.gz
# t2300g1780nc_m0.0.cmp.gz
# t2300g178nc_m0.0.cmp.gz
# t2300g17nc_m0.0.cmp.gz
# t2300g3160nc_m0.0.cmp.gz
# t2300g316nc_m0.0.cmp.gz
# t2300g31nc_m0.0.cmp.gz
# t2300g562nc_m0.0.cmp.gz
# t2300g56nc_m0.0.cmp.gz
# t2400g1000nc_m0.0.cmp.gz
# t2400g100nc_m0.0.cmp.gz
# t2400g1780nc_m0.0.cmp.gz
# t2400g178nc_m0.0.cmp.gz
# t2400g17nc_m0.0.cmp.gz
# t2400g3160nc_m0.0.cmp.gz
# t2400g316nc_m0.0.cmp.gz
# t2400g31nc_m0.0.cmp.gz
# t2400g562nc_m0.0.cmp.gz
# t2400g56nc_m0.0.cmp.gz
# t250g1000nc_m0.0.cmp.gz
# t250g100nc_m0.0.cmp.gz
# t250g1780nc_m0.0.cmp.gz
# t250g178nc_m0.0.cmp.gz
# t250g17nc_m0.0.cmp.gz
# t250g3160nc_m0.0.cmp.gz
# t250g316nc_m0.0.cmp.gz
# t250g31nc_m0.0.cmp.gz
# t250g562nc_m0.0.cmp.gz
# t250g56nc_m0.0.cmp.gz
# t275g1000nc_m0.0.cmp.gz
# t275g100nc_m0.0.cmp.gz
# t275g1780nc_m0.0.cmp.gz
# t275g178nc_m0.0.cmp.gz
# t275g17nc_m0.0.cmp.gz
# t275g3160nc_m0.0.cmp.gz
# t275g316nc_m0.0.cmp.gz
# t275g31nc_m0.0.cmp.gz
# t275g562nc_m0.0.cmp.gz
# t275g56nc_m0.0.cmp.gz
# t300g1000nc_m0.0.cmp.gz
# t300g100nc_m0.0.cmp.gz
# t300g1780nc_m0.0.cmp.gz
# t300g178nc_m0.0.cmp.gz
# t300g17nc_m0.0.cmp.gz
# t300g3160nc_m0.0.cmp.gz
# t300g316nc_m0.0.cmp.gz
# t300g31nc_m0.0.cmp.gz
# t300g562nc_m0.0.cmp.gz
# t300g56nc_m0.0.cmp.gz
# t325g1000nc_m0.0.cmp.gz
# t325g100nc_m0.0.cmp.gz
# t325g1780nc_m0.0.cmp.gz
# t325g178nc_m0.0.cmp.gz
# t325g17nc_m0.0.cmp.gz
# t325g3160nc_m0.0.cmp.gz
# t325g316nc_m0.0.cmp.gz
# t325g31nc_m0.0.cmp.gz
# t325g562nc_m0.0.cmp.gz
# t325g56nc_m0.0.cmp.gz
# t350g1000nc_m0.0.cmp.gz
# t350g100nc_m0.0.cmp.gz
# t350g1780nc_m0.0.cmp.gz
# t350g178nc_m0.0.cmp.gz
# t350g17nc_m0.0.cmp.gz
# t350g3160nc_m0.0.cmp.gz
# t350g316nc_m0.0.cmp.gz
# t350g31nc_m0.0.cmp.gz
# t350g562nc_m0.0.cmp.gz
# t350g56nc_m0.0.cmp.gz
# t375g1000nc_m0.0.cmp.gz
# t375g100nc_m0.0.cmp.gz
# t375g1780nc_m0.0.cmp.gz
# t375g178nc_m0.0.cmp.gz
# t375g17nc_m0.0.cmp.gz
# t375g3160nc_m0.0.cmp.gz
# t375g316nc_m0.0.cmp.gz
# t375g31nc_m0.0.cmp.gz
# t375g562nc_m0.0.cmp.gz
# t375g56nc_m0.0.cmp.gz
# t400g1000nc_m0.0.cmp.gz
# t400g100nc_m0.0.cmp.gz
# t400g1780nc_m0.0.cmp.gz
# t400g178nc_m0.0.cmp.gz
# t400g17nc_m0.0.cmp.gz
# t400g3160nc_m0.0.cmp.gz
# t400g316nc_m0.0.cmp.gz
# t400g31nc_m0.0.cmp.gz
# t400g562nc_m0.0.cmp.gz
# t400g56nc_m0.0.cmp.gz
# t425g1000nc_m0.0.cmp.gz
# t425g100nc_m0.0.cmp.gz
# t425g1780nc_m0.0.cmp.gz
# t425g178nc_m0.0.cmp.gz
# t425g17nc_m0.0.cmp.gz
# t425g3160nc_m0.0.cmp.gz
# t425g316nc_m0.0.cmp.gz
# t425g31nc_m0.0.cmp.gz
# t425g562nc_m0.0.cmp.gz
# t425g56nc_m0.0.cmp.gz
# t450g1000nc_m0.0.cmp.gz
# t450g100nc_m0.0.cmp.gz
# t450g1780nc_m0.0.cmp.gz
# t450g178nc_m0.0.cmp.gz
# t450g17nc_m0.0.cmp.gz
# t450g3160nc_m0.0.cmp.gz
# t450g316nc_m0.0.cmp.gz
# t450g31nc_m0.0.cmp.gz
# t450g562nc_m0.0.cmp.gz
# t450g56nc_m0.0.cmp.gz
# t475g1000nc_m0.0.cmp.gz
# t475g100nc_m0.0.cmp.gz
# t475g1780nc_m0.0.cmp.gz
# t475g178nc_m0.0.cmp.gz
# t475g17nc_m0.0.cmp.gz
# t475g3160nc_m0.0.cmp.gz
# t475g316nc_m0.0.cmp.gz
# t475g31nc_m0.0.cmp.gz
# t475g562nc_m0.0.cmp.gz
# t475g56nc_m0.0.cmp.gz
# t500g1000nc_m0.0.cmp.gz
# t500g100nc_m0.0.cmp.gz
# t500g1780nc_m0.0.cmp.gz
# t500g178nc_m0.0.cmp.gz
# t500g17nc_m0.0.cmp.gz
# t500g3160nc_m0.0.cmp.gz
# t500g316nc_m0.0.cmp.gz
# t500g31nc_m0.0.cmp.gz
# t500g562nc_m0.0.cmp.gz
# t500g56nc_m0.0.cmp.gz
# t525g1000nc_m0.0.cmp.gz
# t525g100nc_m0.0.cmp.gz
# t525g1780nc_m0.0.cmp.gz
# t525g178nc_m0.0.cmp.gz
# t525g17nc_m0.0.cmp.gz
# t525g3160nc_m0.0.cmp.gz
# t525g316nc_m0.0.cmp.gz
# t525g31nc_m0.0.cmp.gz
# t525g562nc_m0.0.cmp.gz
# t525g56nc_m0.0.cmp.gz
# t550g1000nc_m0.0.cmp.gz
# t550g100nc_m0.0.cmp.gz
# t550g1780nc_m0.0.cmp.gz
# t550g178nc_m0.0.cmp.gz
# t550g17nc_m0.0.cmp.gz
# t550g3160nc_m0.0.cmp.gz
# t550g316nc_m0.0.cmp.gz
# t550g31nc_m0.0.cmp.gz
# t550g562nc_m0.0.cmp.gz
# t550g56nc_m0.0.cmp.gz
# t575g1000nc_m0.0.cmp.gz
# t575g100nc_m0.0.cmp.gz
# t575g1780nc_m0.0.cmp.gz
# t575g178nc_m0.0.cmp.gz
# t575g17nc_m0.0.cmp.gz
# t575g3160nc_m0.0.cmp.gz
# t575g316nc_m0.0.cmp.gz
# t575g31nc_m0.0.cmp.gz
# t575g562nc_m0.0.cmp.gz
# t575g56nc_m0.0.cmp.gz
# t600g1000nc_m0.0.cmp.gz
# t600g100nc_m0.0.cmp.gz
# t600g1780nc_m0.0.cmp.gz
# t600g178nc_m0.0.cmp.gz
# t600g17nc_m0.0.cmp.gz
# t600g3160nc_m0.0.cmp.gz
# t600g316nc_m0.0.cmp.gz
# t600g31nc_m0.0.cmp.gz
# t600g562nc_m0.0.cmp.gz
# t600g56nc_m0.0.cmp.gz
# t650g1000nc_m0.0.cmp.gz
# t650g100nc_m0.0.cmp.gz
# t650g1780nc_m0.0.cmp.gz
# t650g178nc_m0.0.cmp.gz
# t650g17nc_m0.0.cmp.gz
# t650g3160nc_m0.0.cmp.gz
# t650g316nc_m0.0.cmp.gz
# t650g31nc_m0.0.cmp.gz
# t650g562nc_m0.0.cmp.gz
# t650g56nc_m0.0.cmp.gz
# t700g1000nc_m0.0.cmp.gz
# t700g100nc_m0.0.cmp.gz
# t700g1780nc_m0.0.cmp.gz
# t700g178nc_m0.0.cmp.gz
# t700g17nc_m0.0.cmp.gz
# t700g3160nc_m0.0.cmp.gz
# t700g316nc_m0.0.cmp.gz
# t700g31nc_m0.0.cmp.gz
# t700g562nc_m0.0.cmp.gz
# t700g56nc_m0.0.cmp.gz
# t750g1000nc_m0.0.cmp.gz
# t750g100nc_m0.0.cmp.gz
# t750g1780nc_m0.0.cmp.gz
# t750g178nc_m0.0.cmp.gz
# t750g17nc_m0.0.cmp.gz
# t750g3160nc_m0.0.cmp.gz
# t750g316nc_m0.0.cmp.gz
# t750g31nc_m0.0.cmp.gz
# t750g562nc_m0.0.cmp.gz
# t750g56nc_m0.0.cmp.gz
# t800g1000nc_m0.0.cmp.gz
# t800g100nc_m0.0.cmp.gz
# t800g1780nc_m0.0.cmp.gz
# t800g178nc_m0.0.cmp.gz
# t800g17nc_m0.0.cmp.gz
# t800g3160nc_m0.0.cmp.gz
# t800g316nc_m0.0.cmp.gz
# t800g31nc_m0.0.cmp.gz
# t800g562nc_m0.0.cmp.gz
# t800g56nc_m0.0.cmp.gz
# t850g1000nc_m0.0.cmp.gz
# t850g100nc_m0.0.cmp.gz
# t850g1780nc_m0.0.cmp.gz
# t850g178nc_m0.0.cmp.gz
# t850g17nc_m0.0.cmp.gz
# t850g3160nc_m0.0.cmp.gz
# t850g316nc_m0.0.cmp.gz
# t850g31nc_m0.0.cmp.gz
# t850g562nc_m0.0.cmp.gz
# t850g56nc_m0.0.cmp.gz
# t900g1000nc_m0.0.cmp.gz
# t900g100nc_m0.0.cmp.gz
# t900g1780nc_m0.0.cmp.gz
# t900g178nc_m0.0.cmp.gz
# t900g17nc_m0.0.cmp.gz
# t900g3160nc_m0.0.cmp.gz
# t900g316nc_m0.0.cmp.gz
# t900g31nc_m0.0.cmp.gz
# t900g562nc_m0.0.cmp.gz
# t900g56nc_m0.0.cmp.gz
# t950g1000nc_m0.0.cmp.gz
# t950g100nc_m0.0.cmp.gz
# t950g1780nc_m0.0.cmp.gz
# t950g178nc_m0.0.cmp.gz
# t950g17nc_m0.0.cmp.gz
# t950g3160nc_m0.0.cmp.gz
# t950g316nc_m0.0.cmp.gz
# t950g31nc_m0.0.cmp.gz
# t950g562nc_m0.0.cmp.gz
# t950g56nc_m0.0.cmp.gz
# --2021-08-24 14:22:39--  https://zenodo.org/record/1309035/files/spectra.tar?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1204848640 (1.1G) [application/octet-stream]
# Saving to: ‘spectra.tar’
#
# spectra.tar         100%[===================>]   1.12G  35.1MB/s    in 2m 12s
#
# 2021-08-24 14:24:52 (8.71 MB/s) - ‘spectra.tar’ saved [1204848640/1204848640]
#
# spectra/
# spectra/parameters
# spectra/sp_t1000g1000nc_m0.0.gz
# spectra/sp_t1000g100nc_m0.0.gz
# spectra/sp_t1000g10nc_m0.0.gz
# spectra/sp_t1000g1780nc_m0.0.gz
# spectra/sp_t1000g178nc_m0.0.gz
# spectra/sp_t1000g17nc_m0.0.gz
# spectra/sp_t1000g3160nc_m0.0.gz
# spectra/sp_t1000g316nc_m0.0.gz
# spectra/sp_t1000g31nc_m0.0.gz
# spectra/sp_t1000g562nc_m0.0.gz
# spectra/sp_t1000g56nc_m0.0.gz
# spectra/sp_t1100g1000nc_m0.0.gz
# spectra/sp_t1100g100nc_m0.0.gz
# spectra/sp_t1100g10nc_m0.0.gz
# spectra/sp_t1100g1780nc_m0.0.gz
# spectra/sp_t1100g178nc_m0.0.gz
# spectra/sp_t1100g17nc_m0.0.gz
# spectra/sp_t1100g3160nc_m0.0.gz
# spectra/sp_t1100g316nc_m0.0.gz
# spectra/sp_t1100g31nc_m0.0.gz
# spectra/sp_t1100g562nc_m0.0.gz
# spectra/sp_t1100g56nc_m0.0.gz
# spectra/sp_t1200g1000nc_m0.0.gz
# spectra/sp_t1200g100nc_m0.0.gz
# spectra/sp_t1200g10nc_m0.0.gz
# spectra/sp_t1200g1780nc_m0.0.gz
# spectra/sp_t1200g178nc_m0.0.gz
# spectra/sp_t1200g17nc_m0.0.gz
# spectra/sp_t1200g3160nc_m0.0.gz
# spectra/sp_t1200g316nc_m0.0.gz
# spectra/sp_t1200g31nc_m0.0.gz
# spectra/sp_t1200g562nc_m0.0.gz
# spectra/sp_t1200g56nc_m0.0.gz
# spectra/sp_t1300g1000nc_m0.0.gz
# spectra/sp_t1300g100nc_m0.0.gz
# spectra/sp_t1300g10nc_m0.0.gz
# spectra/sp_t1300g1780nc_m0.0.gz
# spectra/sp_t1300g178nc_m0.0.gz
# spectra/sp_t1300g17nc_m0.0.gz
# spectra/sp_t1300g3160nc_m0.0.gz
# spectra/sp_t1300g316nc_m0.0.gz
# spectra/sp_t1300g31nc_m0.0.gz
# spectra/sp_t1300g562nc_m0.0.gz
# spectra/sp_t1300g56nc_m0.0.gz
# spectra/sp_t1400g1000nc_m0.0.gz
# spectra/sp_t1400g100nc_m0.0.gz
# spectra/sp_t1400g10nc_m0.0.gz
# spectra/sp_t1400g1780nc_m0.0.gz
# spectra/sp_t1400g178nc_m0.0.gz
# spectra/sp_t1400g17nc_m0.0.gz
# spectra/sp_t1400g3160nc_m0.0.gz
# spectra/sp_t1400g316nc_m0.0.gz
# spectra/sp_t1400g31nc_m0.0.gz
# spectra/sp_t1400g562nc_m0.0.gz
# spectra/sp_t1400g56nc_m0.0.gz
# spectra/sp_t1500g1000nc_m0.0.gz
# spectra/sp_t1500g100nc_m0.0.gz
# spectra/sp_t1500g10nc_m0.0.gz
# spectra/sp_t1500g1780nc_m0.0.gz
# spectra/sp_t1500g178nc_m0.0.gz
# spectra/sp_t1500g17nc_m0.0.gz
# spectra/sp_t1500g3160nc_m0.0.gz
# spectra/sp_t1500g316nc_m0.0.gz
# spectra/sp_t1500g31nc_m0.0.gz
# spectra/sp_t1500g562nc_m0.0.gz
# spectra/sp_t1500g56nc_m0.0.gz
# spectra/sp_t1600g1000nc_m0.0.gz
# spectra/sp_t1600g100nc_m0.0.gz
# spectra/sp_t1600g10nc_m0.0.gz
# spectra/sp_t1600g1780nc_m0.0.gz
# spectra/sp_t1600g178nc_m0.0.gz
# spectra/sp_t1600g17nc_m0.0.gz
# spectra/sp_t1600g3160nc_m0.0.gz
# spectra/sp_t1600g316nc_m0.0.gz
# spectra/sp_t1600g31nc_m0.0.gz
# spectra/sp_t1600g562nc_m0.0.gz
# spectra/sp_t1600g56nc_m0.0.gz
# spectra/sp_t1700g1000nc_m0.0.gz
# spectra/sp_t1700g100nc_m0.0.gz
# spectra/sp_t1700g10nc_m0.0.gz
# spectra/sp_t1700g1780nc_m0.0.gz
# spectra/sp_t1700g178nc_m0.0.gz
# spectra/sp_t1700g17nc_m0.0.gz
# spectra/sp_t1700g3160nc_m0.0.gz
# spectra/sp_t1700g316nc_m0.0.gz
# spectra/sp_t1700g31nc_m0.0.gz
# spectra/sp_t1700g562nc_m0.0.gz
# spectra/sp_t1700g56nc_m0.0.gz
# spectra/sp_t1800g1000nc_m0.0.gz
# spectra/sp_t1800g100nc_m0.0.gz
# spectra/sp_t1800g10nc_m0.0.gz
# spectra/sp_t1800g1780nc_m0.0.gz
# spectra/sp_t1800g178nc_m0.0.gz
# spectra/sp_t1800g17nc_m0.0.gz
# spectra/sp_t1800g3160nc_m0.0.gz
# spectra/sp_t1800g316nc_m0.0.gz
# spectra/sp_t1800g31nc_m0.0.gz
# spectra/sp_t1800g562nc_m0.0.gz
# spectra/sp_t1800g56nc_m0.0.gz
# spectra/sp_t1900g1000nc_m0.0.gz
# spectra/sp_t1900g100nc_m0.0.gz
# spectra/sp_t1900g10nc_m0.0.gz
# spectra/sp_t1900g1780nc_m0.0.gz
# spectra/sp_t1900g178nc_m0.0.gz
# spectra/sp_t1900g17nc_m0.0.gz
# spectra/sp_t1900g3160nc_m0.0.gz
# spectra/sp_t1900g316nc_m0.0.gz
# spectra/sp_t1900g31nc_m0.0.gz
# spectra/sp_t1900g562nc_m0.0.gz
# spectra/sp_t1900g56nc_m0.0.gz
# spectra/sp_t2000g1000nc_m0.0.gz
# spectra/sp_t2000g100nc_m0.0.gz
# spectra/sp_t2000g10nc_m0.0.gz
# spectra/sp_t2000g1780nc_m0.0.gz
# spectra/sp_t2000g178nc_m0.0.gz
# spectra/sp_t2000g17nc_m0.0.gz
# spectra/sp_t2000g3160nc_m0.0.gz
# spectra/sp_t2000g316nc_m0.0.gz
# spectra/sp_t2000g31nc_m0.0.gz
# spectra/sp_t2000g562nc_m0.0.gz
# spectra/sp_t2000g56nc_m0.0.gz
# spectra/sp_t200g1000nc_m0.0.gz
# spectra/sp_t200g100nc_m0.0.gz
# spectra/sp_t200g10nc_m0.0.gz
# spectra/sp_t200g1780nc_m0.0.gz
# spectra/sp_t200g178nc_m0.0.gz
# spectra/sp_t200g17nc_m0.0.gz
# spectra/sp_t200g3160nc_m0.0.gz
# spectra/sp_t200g316nc_m0.0.gz
# spectra/sp_t200g31nc_m0.0.gz
# spectra/sp_t200g562nc_m0.0.gz
# spectra/sp_t200g56nc_m0.0.gz
# spectra/sp_t2100g1000nc_m0.0.gz
# spectra/sp_t2100g100nc_m0.0.gz
# spectra/sp_t2100g10nc_m0.0.gz
# spectra/sp_t2100g1780nc_m0.0.gz
# spectra/sp_t2100g178nc_m0.0.gz
# spectra/sp_t2100g17nc_m0.0.gz
# spectra/sp_t2100g3160nc_m0.0.gz
# spectra/sp_t2100g316nc_m0.0.gz
# spectra/sp_t2100g31nc_m0.0.gz
# spectra/sp_t2100g562nc_m0.0.gz
# spectra/sp_t2100g56nc_m0.0.gz
# spectra/sp_t2200g1000nc_m0.0.gz
# spectra/sp_t2200g100nc_m0.0.gz
# spectra/sp_t2200g10nc_m0.0.gz
# spectra/sp_t2200g1780nc_m0.0.gz
# spectra/sp_t2200g178nc_m0.0.gz
# spectra/sp_t2200g17nc_m0.0.gz
# spectra/sp_t2200g3160nc_m0.0.gz
# spectra/sp_t2200g316nc_m0.0.gz
# spectra/sp_t2200g31nc_m0.0.gz
# spectra/sp_t2200g562nc_m0.0.gz
# spectra/sp_t2200g56nc_m0.0.gz
# spectra/sp_t225g1000nc_m0.0.gz
# spectra/sp_t225g100nc_m0.0.gz
# spectra/sp_t225g10nc_m0.0.gz
# spectra/sp_t225g1780nc_m0.0.gz
# spectra/sp_t225g178nc_m0.0.gz
# spectra/sp_t225g17nc_m0.0.gz
# spectra/sp_t225g3160nc_m0.0.gz
# spectra/sp_t225g316nc_m0.0.gz
# spectra/sp_t225g31nc_m0.0.gz
# spectra/sp_t225g562nc_m0.0.gz
# spectra/sp_t225g56nc_m0.0.gz
# spectra/sp_t2300g1000nc_m0.0.gz
# spectra/sp_t2300g100nc_m0.0.gz
# spectra/sp_t2300g10nc_m0.0.gz
# spectra/sp_t2300g1780nc_m0.0.gz
# spectra/sp_t2300g178nc_m0.0.gz
# spectra/sp_t2300g17nc_m0.0.gz
# spectra/sp_t2300g3160nc_m0.0.gz
# spectra/sp_t2300g316nc_m0.0.gz
# spectra/sp_t2300g31nc_m0.0.gz
# spectra/sp_t2300g562nc_m0.0.gz
# spectra/sp_t2300g56nc_m0.0.gz
# spectra/sp_t2400g1000nc_m0.0.gz
# spectra/sp_t2400g100nc_m0.0.gz
# spectra/sp_t2400g10nc_m0.0.gz
# spectra/sp_t2400g1780nc_m0.0.gz
# spectra/sp_t2400g178nc_m0.0.gz
# spectra/sp_t2400g17nc_m0.0.gz
# spectra/sp_t2400g3160nc_m0.0.gz
# spectra/sp_t2400g316nc_m0.0.gz
# spectra/sp_t2400g31nc_m0.0.gz
# spectra/sp_t2400g562nc_m0.0.gz
# spectra/sp_t2400g56nc_m0.0.gz
# spectra/sp_t250g1000nc_m0.0.gz
# spectra/sp_t250g100nc_m0.0.gz
# spectra/sp_t250g10nc_m0.0.gz
# spectra/sp_t250g1780nc_m0.0.gz
# spectra/sp_t250g178nc_m0.0.gz
# spectra/sp_t250g17nc_m0.0.gz
# spectra/sp_t250g3160nc_m0.0.gz
# spectra/sp_t250g316nc_m0.0.gz
# spectra/sp_t250g31nc_m0.0.gz
# spectra/sp_t250g562nc_m0.0.gz
# spectra/sp_t250g56nc_m0.0.gz
# spectra/sp_t275g1000nc_m0.0.gz
# spectra/sp_t275g100nc_m0.0.gz
# spectra/sp_t275g10nc_m0.0.gz
# spectra/sp_t275g1780nc_m0.0.gz
# spectra/sp_t275g178nc_m0.0.gz
# spectra/sp_t275g17nc_m0.0.gz
# spectra/sp_t275g3160nc_m0.0.gz
# spectra/sp_t275g316nc_m0.0.gz
# spectra/sp_t275g31nc_m0.0.gz
# spectra/sp_t275g562nc_m0.0.gz
# spectra/sp_t275g56nc_m0.0.gz
# spectra/sp_t300g1000nc_m0.0.gz
# spectra/sp_t300g100nc_m0.0.gz
# spectra/sp_t300g10nc_m0.0.gz
# spectra/sp_t300g1780nc_m0.0.gz
# spectra/sp_t300g178nc_m0.0.gz
# spectra/sp_t300g17nc_m0.0.gz
# spectra/sp_t300g3160nc_m0.0.gz
# spectra/sp_t300g316nc_m0.0.gz
# spectra/sp_t300g31nc_m0.0.gz
# spectra/sp_t300g562nc_m0.0.gz
# spectra/sp_t300g56nc_m0.0.gz
# spectra/sp_t325g1000nc_m0.0.gz
# spectra/sp_t325g100nc_m0.0.gz
# spectra/sp_t325g10nc_m0.0.gz
# spectra/sp_t325g1780nc_m0.0.gz
# spectra/sp_t325g178nc_m0.0.gz
# spectra/sp_t325g17nc_m0.0.gz
# spectra/sp_t325g3160nc_m0.0.gz
# spectra/sp_t325g316nc_m0.0.gz
# spectra/sp_t325g31nc_m0.0.gz
# spectra/sp_t325g562nc_m0.0.gz
# spectra/sp_t325g56nc_m0.0.gz
# spectra/sp_t350g1000nc_m0.0.gz
# spectra/sp_t350g100nc_m0.0.gz
# spectra/sp_t350g10nc_m0.0.gz
# spectra/sp_t350g1780nc_m0.0.gz
# spectra/sp_t350g178nc_m0.0.gz
# spectra/sp_t350g17nc_m0.0.gz
# spectra/sp_t350g3160nc_m0.0.gz
# spectra/sp_t350g316nc_m0.0.gz
# spectra/sp_t350g31nc_m0.0.gz
# spectra/sp_t350g562nc_m0.0.gz
# spectra/sp_t350g56nc_m0.0.gz
# spectra/sp_t375g1000nc_m0.0.gz
# spectra/sp_t375g100nc_m0.0.gz
# spectra/sp_t375g10nc_m0.0.gz
# spectra/sp_t375g1780nc_m0.0.gz
# spectra/sp_t375g178nc_m0.0.gz
# spectra/sp_t375g17nc_m0.0.gz
# spectra/sp_t375g3160nc_m0.0.gz
# spectra/sp_t375g316nc_m0.0.gz
# spectra/sp_t375g31nc_m0.0.gz
# spectra/sp_t375g562nc_m0.0.gz
# spectra/sp_t375g56nc_m0.0.gz
# spectra/sp_t400g1000nc_m0.0.gz
# spectra/sp_t400g100nc_m0.0.gz
# spectra/sp_t400g10nc_m0.0.gz
# spectra/sp_t400g1780nc_m0.0.gz
# spectra/sp_t400g178nc_m0.0.gz
# spectra/sp_t400g17nc_m0.0.gz
# spectra/sp_t400g3160nc_m0.0.gz
# spectra/sp_t400g316nc_m0.0.gz
# spectra/sp_t400g31nc_m0.0.gz
# spectra/sp_t400g562nc_m0.0.gz
# spectra/sp_t400g56nc_m0.0.gz
# spectra/sp_t425g1000nc_m0.0.gz
# spectra/sp_t425g100nc_m0.0.gz
# spectra/sp_t425g10nc_m0.0.gz
# spectra/sp_t425g1780nc_m0.0.gz
# spectra/sp_t425g178nc_m0.0.gz
# spectra/sp_t425g17nc_m0.0.gz
# spectra/sp_t425g3160nc_m0.0.gz
# spectra/sp_t425g316nc_m0.0.gz
# spectra/sp_t425g31nc_m0.0.gz
# spectra/sp_t425g562nc_m0.0.gz
# spectra/sp_t425g56nc_m0.0.gz
# spectra/sp_t450g1000nc_m0.0.gz
# spectra/sp_t450g100nc_m0.0.gz
# spectra/sp_t450g10nc_m0.0.gz
# spectra/sp_t450g1780nc_m0.0.gz
# spectra/sp_t450g178nc_m0.0.gz
# spectra/sp_t450g17nc_m0.0.gz
# spectra/sp_t450g3160nc_m0.0.gz
# spectra/sp_t450g316nc_m0.0.gz
# spectra/sp_t450g31nc_m0.0.gz
# spectra/sp_t450g562nc_m0.0.gz
# spectra/sp_t450g56nc_m0.0.gz
# spectra/sp_t475g1000nc_m0.0.gz
# spectra/sp_t475g100nc_m0.0.gz
# spectra/sp_t475g10nc_m0.0.gz
# spectra/sp_t475g1780nc_m0.0.gz
# spectra/sp_t475g178nc_m0.0.gz
# spectra/sp_t475g17nc_m0.0.gz
# spectra/sp_t475g3160nc_m0.0.gz
# spectra/sp_t475g316nc_m0.0.gz
# spectra/sp_t475g31nc_m0.0.gz
# spectra/sp_t475g562nc_m0.0.gz
# spectra/sp_t475g56nc_m0.0.gz
# spectra/sp_t500g1000nc_m0.0.gz
# spectra/sp_t500g100nc_m0.0.gz
# spectra/sp_t500g10nc_m0.0.gz
# spectra/sp_t500g1780nc_m0.0.gz
# spectra/sp_t500g178nc_m0.0.gz
# spectra/sp_t500g17nc_m0.0.gz
# spectra/sp_t500g3160nc_m0.0.gz
# spectra/sp_t500g316nc_m0.0.gz
# spectra/sp_t500g31nc_m0.0.gz
# spectra/sp_t500g562nc_m0.0.gz
# spectra/sp_t500g56nc_m0.0.gz
# spectra/sp_t525g1000nc_m0.0.gz
# spectra/sp_t525g100nc_m0.0.gz
# spectra/sp_t525g10nc_m0.0.gz
# spectra/sp_t525g1780nc_m0.0.gz
# spectra/sp_t525g178nc_m0.0.gz
# spectra/sp_t525g17nc_m0.0.gz
# spectra/sp_t525g3160nc_m0.0.gz
# spectra/sp_t525g316nc_m0.0.gz
# spectra/sp_t525g31nc_m0.0.gz
# spectra/sp_t525g562nc_m0.0.gz
# spectra/sp_t525g56nc_m0.0.gz
# spectra/sp_t550g1000nc_m0.0.gz
# spectra/sp_t550g100nc_m0.0.gz
# spectra/sp_t550g10nc_m0.0.gz
# spectra/sp_t550g1780nc_m0.0.gz
# spectra/sp_t550g178nc_m0.0.gz
# spectra/sp_t550g17nc_m0.0.gz
# spectra/sp_t550g3160nc_m0.0.gz
# spectra/sp_t550g316nc_m0.0.gz
# spectra/sp_t550g31nc_m0.0.gz
# spectra/sp_t550g562nc_m0.0.gz
# spectra/sp_t550g56nc_m0.0.gz
# spectra/sp_t575g1000nc_m0.0.gz
# spectra/sp_t575g100nc_m0.0.gz
# spectra/sp_t575g10nc_m0.0.gz
# spectra/sp_t575g1780nc_m0.0.gz
# spectra/sp_t575g178nc_m0.0.gz
# spectra/sp_t575g17nc_m0.0.gz
# spectra/sp_t575g3160nc_m0.0.gz
# spectra/sp_t575g316nc_m0.0.gz
# spectra/sp_t575g31nc_m0.0.gz
# spectra/sp_t575g562nc_m0.0.gz
# spectra/sp_t575g56nc_m0.0.gz
# spectra/sp_t600g1000nc_m0.0.gz
# spectra/sp_t600g100nc_m0.0.gz
# spectra/sp_t600g10nc_m0.0.gz
# spectra/sp_t600g1780nc_m0.0.gz
# spectra/sp_t600g178nc_m0.0.gz
# spectra/sp_t600g17nc_m0.0.gz
# spectra/sp_t600g3160nc_m0.0.gz
# spectra/sp_t600g316nc_m0.0.gz
# spectra/sp_t600g31nc_m0.0.gz
# spectra/sp_t600g562nc_m0.0.gz
# spectra/sp_t600g56nc_m0.0.gz
# spectra/sp_t650g1000nc_m0.0.gz
# spectra/sp_t650g100nc_m0.0.gz
# spectra/sp_t650g10nc_m0.0.gz
# spectra/sp_t650g1780nc_m0.0.gz
# spectra/sp_t650g178nc_m0.0.gz
# spectra/sp_t650g17nc_m0.0.gz
# spectra/sp_t650g3160nc_m0.0.gz
# spectra/sp_t650g316nc_m0.0.gz
# spectra/sp_t650g31nc_m0.0.gz
# spectra/sp_t650g562nc_m0.0.gz
# spectra/sp_t650g56nc_m0.0.gz
# spectra/sp_t700g1000nc_m0.0.gz
# spectra/sp_t700g100nc_m0.0.gz
# spectra/sp_t700g10nc_m0.0.gz
# spectra/sp_t700g1780nc_m0.0.gz
# spectra/sp_t700g178nc_m0.0.gz
# spectra/sp_t700g17nc_m0.0.gz
# spectra/sp_t700g3160nc_m0.0.gz
# spectra/sp_t700g316nc_m0.0.gz
# spectra/sp_t700g31nc_m0.0.gz
# spectra/sp_t700g562nc_m0.0.gz
# spectra/sp_t700g56nc_m0.0.gz
# spectra/sp_t750g1000nc_m0.0.gz
# spectra/sp_t750g100nc_m0.0.gz
# spectra/sp_t750g10nc_m0.0.gz
# spectra/sp_t750g1780nc_m0.0.gz
# spectra/sp_t750g178nc_m0.0.gz
# spectra/sp_t750g17nc_m0.0.gz
# spectra/sp_t750g3160nc_m0.0.gz
# spectra/sp_t750g316nc_m0.0.gz
# spectra/sp_t750g31nc_m0.0.gz
# spectra/sp_t750g562nc_m0.0.gz
# spectra/sp_t750g56nc_m0.0.gz
# spectra/sp_t800g1000nc_m0.0.gz
# spectra/sp_t800g100nc_m0.0.gz
# spectra/sp_t800g10nc_m0.0.gz
# spectra/sp_t800g1780nc_m0.0.gz
# spectra/sp_t800g178nc_m0.0.gz
# spectra/sp_t800g17nc_m0.0.gz
# spectra/sp_t800g3160nc_m0.0.gz
# spectra/sp_t800g316nc_m0.0.gz
# spectra/sp_t800g31nc_m0.0.gz
# spectra/sp_t800g562nc_m0.0.gz
# spectra/sp_t800g56nc_m0.0.gz
# spectra/sp_t850g1000nc_m0.0.gz
# spectra/sp_t850g100nc_m0.0.gz
# spectra/sp_t850g10nc_m0.0.gz
# spectra/sp_t850g1780nc_m0.0.gz
# spectra/sp_t850g178nc_m0.0.gz
# spectra/sp_t850g17nc_m0.0.gz
# spectra/sp_t850g3160nc_m0.0.gz
# spectra/sp_t850g316nc_m0.0.gz
# spectra/sp_t850g31nc_m0.0.gz
# spectra/sp_t850g562nc_m0.0.gz
# spectra/sp_t850g56nc_m0.0.gz
# spectra/sp_t900g1000nc_m0.0.gz
# spectra/sp_t900g100nc_m0.0.gz
# spectra/sp_t900g10nc_m0.0.gz
# spectra/sp_t900g1780nc_m0.0.gz
# spectra/sp_t900g178nc_m0.0.gz
# spectra/sp_t900g17nc_m0.0.gz
# spectra/sp_t900g3160nc_m0.0.gz
# spectra/sp_t900g316nc_m0.0.gz
# spectra/sp_t900g31nc_m0.0.gz
# spectra/sp_t900g562nc_m0.0.gz
# spectra/sp_t900g56nc_m0.0.gz
# spectra/sp_t950g1000nc_m0.0.gz
# spectra/sp_t950g100nc_m0.0.gz
# spectra/sp_t950g10nc_m0.0.gz
# spectra/sp_t950g1780nc_m0.0.gz
# spectra/sp_t950g178nc_m0.0.gz
# spectra/sp_t950g17nc_m0.0.gz
# spectra/sp_t950g3160nc_m0.0.gz
# spectra/sp_t950g316nc_m0.0.gz
# spectra/sp_t950g31nc_m0.0.gz
# spectra/sp_t950g562nc_m0.0.gz
# spectra/sp_t950g56nc_m0.0.gz
# --2021-08-24 14:25:14--  https://zenodo.org/record/3992294/files/virga.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4007293 (3.8M) [application/octet-stream]
# Saving to: ‘virga.zip’
#
# virga.zip           100%[===================>]   3.82M  7.67MB/s    in 0.5s
#
# 2021-08-24 14:25:16 (7.67 MB/s) - ‘virga.zip’ saved [4007293/4007293]
#
# Archive:  virga.zip
#    creating: virga_1e-7/
#   inflating: virga_1e-7/H2O.refrind
#   inflating: virga_1e-7/Fe.refrind
#    creating: __MACOSX/
#    creating: __MACOSX/virga_1e-7/
#   inflating: __MACOSX/virga_1e-7/._Fe.refrind
#   inflating: virga_1e-7/NH3.refrind
#   inflating: virga_1e-7/H2O.mieff
#   inflating: virga_1e-7/MgSiO3.mieff
#   inflating: virga_1e-7/TiO2.mieff
#   inflating: virga_1e-7/CH4.mieff
#   inflating: virga_1e-7/Na2S.mieff
#   inflating: virga_1e-7/Al2O3.refrind
#   inflating: virga_1e-7/MnS.refrind
#   inflating: virga_1e-7/KCl.refrind
#   inflating: __MACOSX/virga_1e-7/._KCl.refrind
#   inflating: virga_1e-7/MgSiO3.refrind
#   inflating: virga_1e-7/Fe.mieff
#   inflating: virga_1e-7/Cr.mieff
#   inflating: virga_1e-7/Na2S.refrind
#   inflating: virga_1e-7/TiO2.refrind
#   inflating: __MACOSX/virga_1e-7/._TiO2.refrind
#   inflating: virga_1e-7/NH3.mieff
#   inflating: virga_1e-7/CH4.refrind
#   inflating: __MACOSX/virga_1e-7/._CH4.refrind
#   inflating: virga_1e-7/Cr.refrind
#   inflating: virga_1e-7/Al2O3.mieff
#   inflating: virga_1e-7/KCl.mieff
#   inflating: virga_1e-7/MnS.mieff
#   inflating: virga_1e-7/ZnS.refrind
#   inflating: __MACOSX/virga_1e-7/._ZnS.refrind
#   inflating: virga_1e-7/Mg2SiO4.refrind
#   inflating: virga_1e-7/ZnS.mieff
#   inflating: virga_1e-7/Mg2SiO4.mieff
#   inflating: __MACOSX/virga_1e-7/._Mg2SiO4.mieff

# %% [markdown]
# #### Verify downloaded directories
# The next cell will show the downloaded files.

# %%
# Verify downloaded directories and files
# Change to the DiskModel Path
os.chdir (spectroscopy_path)
def check_dir(dir):
  if (os.path.isdir(dir)):
    print("Directory '%s' exists" %dir)
  else:
    print("Directory '%s' does not exist, Submit a Github Issue on PICASO Github" %dir)

check_dir(picaso_dir)
check_dir(reference_dir)
check_dir(opacities_dir)
check_dir(trds_dir)
check_dir(grid_dir)
check_dir(profile_dir)
check_dir(spectra_dir)
check_dir(virga_dir)
# Out:
# Directory '/content/drive/MyDrive/PICASO/code/picaso' exists
# Directory '/content/drive/MyDrive/PICASO/code/picaso/reference' exists
# Directory '/content/drive/MyDrive/PICASO/code/picaso/reference/opacities' exists
# Directory '/content/drive/MyDrive/PICASO/code/grp/redcat/trds' exists
# Directory '/content/drive/MyDrive/PICASO/code/grp/redcat/trds/grid' exists
# Directory '/content/drive/MyDrive/PICASO/code/profile' exists
# Directory '/content/drive/MyDrive/PICASO/code/spectra' exists
# Directory '/content/drive/MyDrive/PICASO/code/virga_1e-7' exists

# %%
# To save space you can delete the tar and zip files.  
# drive directly.  https://drive.google.com/drive/my-drive
os.chdir(spectroscopy_path)
# !rm synphot3.tar
# !rm profile.tar
# !rm spectra.tar
# !rm virga.zip
